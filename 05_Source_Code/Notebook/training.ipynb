# %% [markdown]
# # 2. Training
#
# Notebook ini memanggil modul di folder `../Script/`. Logika utama ada di sana (satu sumber kebenaran). Sebelum menjalankan, pastikan dataset sudah diunduh ke `04_Dataset/Raw_Dataset/` (lihat `Dataset_Source.txt`).
#
# Replikasi: Pratiwi, Asmara & Rahutomo (2017), ICTS. Dataset Mendeley CC BY 4.0.

# %% [markdown]
# ## Langkah 1 — Setup

# %%
import sys, os
sys.path.append(os.path.abspath('../Script'))
from config import SEED, set_seed
set_seed(SEED)
print('Seed di-set:', SEED)

# %% [markdown]
# ## Langkah 2 — Latih semua model
# Melatih metode usulan (Naïve Bayes) + baseline (SVM, Logistic Regression) pada 3 skema split, lalu menyimpan hasil & model terbaik.
#
# > Catatan: di skrip ini training & evaluasi digabung dalam `train_eval.main()` karena dataset kecil. Sel berikut menjalankan keduanya.

# %%
import train_eval
train_eval.main()

# %% [markdown]
# Model terbaik tersimpan di `06_Model/best_model_nb.pkl`. Hasil di `07_Hasil_Eksperimen/`. Analisis di `evaluation.ipynb`.
