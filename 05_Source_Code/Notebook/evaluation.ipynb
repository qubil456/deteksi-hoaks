# %% [markdown]
# # 3. Evaluation & Analisis
#
# Notebook ini memanggil modul di folder `../Script/`. Logika utama ada di sana (satu sumber kebenaran). Sebelum menjalankan, pastikan dataset sudah diunduh ke `04_Dataset/Raw_Dataset/` (lihat `Dataset_Source.txt`).
#
# Replikasi: Pratiwi, Asmara & Rahutomo (2017), ICTS. Dataset Mendeley CC BY 4.0.

# %% [markdown]
# ## Langkah 1 — Setup

# %%
import sys, os
sys.path.append(os.path.abspath('../Script'))
from config import SEED, set_seed
set_seed(SEED)
print('Seed di-set:', SEED)

# %% [markdown]
# ## Langkah 2 — Muat hasil eksperimen

# %%
import pandas as pd
from config import RESULT_DIR
hasil = pd.read_csv(RESULT_DIR/'hasil_replikasi.csv')
hasil

# %% [markdown]
# ## Langkah 3 — Tabel perbandingan (rata-rata antar skema)

# %%
comp = pd.read_csv(RESULT_DIR/'perbandingan_usulan_baseline.csv')
comp

# %% [markdown]
# ## Langkah 4 — Confusion matrix
# Tersimpan di `08_Visualisasi/`. Tampilkan salah satu:

# %%
from config import VIZ_DIR
from IPython.display import Image, display
display(Image(filename=str(VIZ_DIR/'confusion_NB_80-20.png')))

# %% [markdown]
# ## Analisis
# Isi pembahasan di sini (kriteria N tugas): apakah usulan > baseline, faktor penyebab, kelebihan & kelemahan metode, potensi pengembangan (mis. Sastrawi untuk stemming, dataset lebih besar). Jangan hanya tampilkan angka.
